# %%
import numpy as np 
import faiss
import sys
import time
module_path = '/home/cpanourg/projects/2-hdvc/'

if module_path not in sys.path:
    sys.path.append(module_path)

from src.utils import read_fvecs

# %%
# Loading the GIST dataset
db = np.array(read_fvecs('/data/cpanourg/2-hdvc/gist/gist_base.fvecs'))
qr = np.array(read_fvecs('/data/cpanourg/2-hdvc/gist/gist_query.fvecs'))

nb = db.shape[0]  # Number of database vectors
dim = db.shape[1]  # Dimensionality of the vectors
# Out:
# Reading File - /data/cpanourg/2-hdvc/gist/gist_base.fvecs:(1000000, 960)
# Reading File - /data/cpanourg/2-hdvc/gist/gist_query.fvecs:(1000, 960)
