# %%
import pandas as pd 

pd.read_csv('/data/cpanourg/2-hdvc/data/datasets_metadata.csv')
# Out:
#          Dataset Name         Domain / Type Dimensionality    Scale (Approx.)  \
# 0              SIFT1M      Image embeddings            128                 1M
# 1             SIFT10M      Image embeddings            128                10M
# 2              BigANN      Image embeddings            128                 1B
# 3              Deep1M      Image embeddings         96–256                 1M
# 4              Deep1B      Image embeddings         96–256                 1B
# 5              GIST1M     Image descriptors            960                 1M
# 6               Trevi         Image patches            960                10K
# 7               MNIST          Image digits            784                60K
# 8               CIFAR      Image embeddings           1024                60K
# 9         ImageNet-1K  Image classification       512–1024               1.3M
# 10        ImageNet-4K  Image classification           4096           Millions
# ...
